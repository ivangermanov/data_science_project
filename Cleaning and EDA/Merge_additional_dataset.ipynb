# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
orders_path_original = '../orders_cleaned.csv'
orders_path_additional = '../orders_additional_cleaned.csv'

df_original = pd.read_csv(orders_path_original,
                        dtype=
                        {'Customer number': object,
                         'Gender': 'category',
                         'PoR': object,
                         'Order number': object,
                         'Product number': object,
                         'Sub category': 'category',
                         'Category': 'category',
                         'Count': np.int16,
                         'Price': np.float64,
                         'EDT': np.int16,
                         'ADT': np.int16,
                         'RoR': object,
                         'Rating': np.int8})

df_additional = pd.read_csv(orders_path_additional,
                        dtype=
                        {'Customer number': object,
                         'Gender': 'category',
                         'PoR': object,
                         'Order number': object,
                         'Product number': object,
                         'Sub category': 'category',
                         'Category': 'category',
                         'Count': np.int16,
                         'Price': np.float64,
                         'EDT': np.int16,
                         'ADT': np.int16,
                         'RoR': object,
                         'Rating': np.int8})

# %%
df_original.head(5)
# Out:
#   Customer number         DoB Gender            PoR Order number  Order date  \
# 0         1063418  15-01-1944  Woman    Bloemendaal      1251137  20-12-2014
# 1         1062078  17-01-1934    Man        De Bilt      1658762  03-11-2017
# 2         1007060  14-01-1947    Man     Doetinchem       106526  08-06-2013
# 3         1063418  15-01-1944  Woman    Bloemendaal      1251137  20-12-2014
# 4         1063290  08-01-1971  Woman  Franekeradeel       439149  06-01-2015
#
#   Product number        Sub category           Category  Count    Price  EDT  \
# 0  5146308036084       Garden chairs   Garden furniture      1  1090.82    2
# 1  8119187109467             Torches     Garden heating      6   385.92    4
# 2  6110364066490        Leaf blowers     Garden reamers      2   173.78    3
# 3  8172375031575                Hoes  Garden hand tools      4    45.64    5
# 4  8111132296154  Insects and vermin            Control      1   114.24    1
#
#    ADT                RoR  Rating
# ...

# %%
df_merged = pd.concat([df_original, df_additional])

# %%
df_merged.head()
# Out:
#   Customer number         DoB Gender            PoR Order number  Order date  \
# 0         1063418  15-01-1944  Woman    Bloemendaal      1251137  20-12-2014
# 1         1062078  17-01-1934    Man        De Bilt      1658762  03-11-2017
# 2         1007060  14-01-1947    Man     Doetinchem       106526  08-06-2013
# 3         1063418  15-01-1944  Woman    Bloemendaal      1251137  20-12-2014
# 4         1063290  08-01-1971  Woman  Franekeradeel       439149  06-01-2015
#
#   Product number        Sub category           Category  Count    Price  EDT  \
# 0  5146308036084       Garden chairs   Garden furniture      1  1090.82    2
# 1  8119187109467             Torches     Garden heating      6   385.92    4
# 2  6110364066490        Leaf blowers     Garden reamers      2   173.78    3
# 3  8172375031575                Hoes  Garden hand tools      4    45.64    5
# 4  8111132296154  Insects and vermin            Control      1   114.24    1
#
#    ADT                RoR  Rating
# ...

# %%
df_merged.to_csv('../orders_merged.csv', index=False)
